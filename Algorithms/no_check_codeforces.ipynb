# %% [markdown]
# ![image.png](attachment:image.png)
# https://codeforces.com/problemset/problem/4/A

# %%
"""1 exampl."""
int_i = int(input())
print(["YES", "NO"][int_i % 2 or int_i < 3])

# %%
int_i = int(input())
if int_i % 2 == 0 and int_i != 2:
    print("YES")
else:
    print("NO")

# %%
int_n = int(input())
if int_n != 2 and int_n % 2 == 0:
    print("YES")
else:
    print("NO")
